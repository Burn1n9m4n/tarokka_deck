# %%
# %load_ext lab_black

# %% [markdown]
# # MAKE COPY BEFORE SAVING

# %%
from matplotlib import pyplot
import matplotlib.gridspec as gridspec
import pandas as pd
import numpy as np

# import pyarrow.parquet as pq
# import s3fs
from typing import List

from pathlib import Path

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# # Functions

# %% [markdown]
# ### Create Tarokka Deck

# %%
def create_tarokka_deck():
    tarokka_deck = pd.read_excel(
        "20200322_tarokka_deck_cos.xlsx", encoding="ISO-8859-1", sep="\t", quoting=3
    )
    tarokka_deck["book_suit"] = (
        tarokka_deck.loc[~tarokka_deck.suit.str.contains("high")]
        .suit.str.split("_")
        .apply(lambda x: x[1].title() + " of " + x[0].title() + "s")
    )
    cols = tarokka_deck.columns.tolist()
    cols = cols[0:2] + cols[-1:] + cols[2:-1]
    tarokka_deck = tarokka_deck.reindex(columns=cols)
    tarokka_deck = tarokka_deck.drop(columns=["suit"]).rename(
        columns={
            "book_suit": "suit",
            "clue": "treasure_clue",
            "location": "treasure_location",
        }
    )
    tarokka_deck.suit = tarokka_deck.suit.fillna("High")
    tarokka_deck = tarokka_deck.fillna("na")
    return tarokka_deck

# %%
# deck.loc[deck.suit.str.contains("high")]
#### Test code to see how often the while loop is triggered.
#### By my calculations it should happens ~23/1,000,000 of the time, but I'm not seeing that.
def draw_cards():
    tarokka_deck = create_tarokka_deck()
    common_deck = tarokka_deck.loc[~tarokka_deck.suit.str.contains("High")]
    high_deck = tarokka_deck.loc[tarokka_deck.suit.str.contains("High")]
    common_draws = common_deck[
        ["card_name", "suit", "treasure_clue", "treasure_location"]
    ].sample(3)

    high_draws = high_deck[
        [
            "card_name",
            "strahd_enemy_clue",
            "strahd_enemy",
            "strahd_location_clue",
            "strahd_location",
        ]
    ].sample(2)
    high_draw_check = high_draws.card_name.str.split("_").tolist()
    if high_draw_check[0][0] == high_draw_check[1][0]:
        while high_draw_check[0][0] == high_draw_check[1][0]:
            high_draws = high_deck[
                [
                    "card_name",
                    "strahd_enemy_clue",
                    "strahd_enemy",
                    "strahd_location_clue",
                    "strahd_location",
                ]
            ].sample(2)
            high_draw_check = high_draws.card_name.str.split("_").tolist()
    common_draws = common_draws.reset_index(drop=True)
    high_draws = high_draws.reset_index(drop=True)
    return common_draws, high_draws

# %%
# common_draws.iloc[[0]]
tarokka_deck = create_tarokka_deck()
tarokka_deck.head()
# Out:
#       card_name  suit treasure_clue treasure_location  \
# 0      artifact  High            na                na
# 1         beast  High            na                na
# 2  broken_one_a  High            na                na
# 3  broken_one_b  High            na                na
# 4      darklord  High            na                na
#
#                                    strahd_enemy_clue  \
# 0  Look for an entertaining man with a monkey. Th...
# 1  A werewolf holds a secret hatred for your enem...
# 2  Your greatest ally will be a wizard. His mind ...
# 3  I see a man of faith whose sanity hangs by a t...
# 4  Ah, the worst of all truths: You must face the...
#
#                                         strahd_enemy  \
# 0  This card refers to Rictavio (see appendix D),...
# 1  This card refers to the werewolf Zuleika Toran...
# 2  This card refers to the Mad Mage of Mount Bara...
# 3  This card refers to Donavich, the priest in th...
# 4    There is no NPC who can inspire the characters.
#
#                                 strahd_location_clue  \
# 0  He lurks in the darkness where the morning lig...
# 1                 The beast sits on his dark throne.
# 2  He haunts the tomb of the man he envied above ...
# 3  He haunts the tomb of the man he envied above ...
# 4  He lurks in the depths of darkness, in the one...
#
#                                      strahd_location
# 0  Strahd faces the characters in the chapel (are...
# 1  Strahd faces the characters in the audience ha...
# 2  Strahd faces the characters in Sergei’s tomb (...
# 3  Strahd faces the characters in Sergei’s tomb (...
# 4  Strahd faces the characters in his tomb (area ...

# %%
tarokka_deck.loc[tarokka_deck.index == 40]
# Out:
#    card_name        suit                                      treasure_clue  \
# 40     miser  9 of Coins  Look for a fortress inside a fortress, in a pl...
#
#                                     treasure_location strahd_enemy_clue  \
# 40  The treasure lies in Castle Ravenloft’s treasu...                na
#
#    strahd_enemy strahd_location_clue strahd_location
# 40           na                   na              na

# %%
tarokka_deck.loc[
    (tarokka_deck.suit == "High") & ~(tarokka_deck.card_name.str.endswith("_b"))
].shape
# Out:
# (14, 8)

# %%
common_draws, high_draws = draw_cards()
file_path = Path().absolute()
common_card_name_search = common_draws.card_name.unique().tolist()
high_card_name_search = high_draws.card_name.unique().tolist()

common_card_name = common_draws.card_name.str.title().unique().tolist()
high_card_name = high_draws.card_name.str.title().unique().tolist()
high_card_name_first = high_card_name[0].split("_")[0]
high_card_name_second = high_card_name[1].split("_")[0]

suit = common_draws.suit.unique().tolist()
treasure_clue = common_draws.treasure_clue.unique().tolist()
treasure_location = common_draws.treasure_location.tolist()
strahd_enemy_clue = high_draws.strahd_enemy_clue.tolist()
strahd_enemy_clue_dm = high_draws.strahd_enemy.tolist()
strahd_location_clue = high_draws.strahd_location_clue.tolist()
strahd_location_clue_dm = high_draws.strahd_location.tolist()

ind = 0
fig, ax = pyplot.subplots(1, 3, squeeze=False)  # , sharex="col", sharey="row")
# pyplot.tight_layout()
gs1 = gridspec.GridSpec(1, 3)
gs1.update(wspace=0, hspace=0)
ax[0, 0].set_axis_off()
ax[0, 1].set_axis_off()
ax[0, 2].set_axis_off()
pyplot.rcParams["image.aspect"]
# ax[2, 2].set_axis_off()
data = pyplot.imread(f"{file_path}\\card_images\\{common_card_name_search[ind]}.png")

#         pyplot.rcParams["figure.figsize"] = [30, 15]
#         fig.suptitle("Treasure Cards\n", fontsize=40)
# pyplot.rcParams["image.aspect"]

ax[0, 0].imshow(data)
ax[0, 0].axis("off")
pyplot.tight_layout()
# pyplot.rcParams["image.aspect"]
treasure_clues_dm = {}
print(f"The Tome of Strahd")
print(
    f"This card tells of history. Knowledge of the ancient will help you better understand your enemy.\n"
)

print(f"-{suit[ind]} -- {common_card_name[ind]}")
print(f"{treasure_clue[ind]}\n")
treasure_clues_dm["Tome of Strahd"] = treasure_location[ind]

ind += 1
# fig, ax = plt.subplots(3, 3, squeeze=False)#, sharex="col", sharey="row")

data = pyplot.imread(f"{file_path}\\card_images\\{common_card_name_search[ind]}.png")

#         pyplot.rcParams["figure.figsize"] = [30, 15]

# pyplot.rcParams["image.aspect"]

ax[0, 1].imshow(data)
ax[0, 1].axis("off")

print(f"The Holy Symbol of Ravenkind")
print(
    f"This card tells of of a powerful force for good and protection, a holy symbol of great hope.\n"
)

print(f"-{suit[ind]} -- {common_card_name[ind]}")
print(f"{treasure_clue[ind]}\n")
treasure_clues_dm["Holy Symbol of Ravenkind"] = treasure_location[ind]

ind += 1

data = pyplot.imread(f"{file_path}\\card_images\\{common_card_name_search[ind]}.png")

#         pyplot.rcParams["figure.figsize"] = [30, 15]
#         fig.suptitle("Treasure Cards\n", fontsize=40)
# pyplot.rcParams["image.aspect"]

ax[0, 2].imshow(data)
# pyplot.rcParams["image.aspect"]
ax[0, 2].axis("off")

print(f"The Sunsword")
print(
    f"This is a card of power and strength. It tells of a weapon of vengeance: a sword of sunlight.\n"
)

print(f"-{suit[ind]} -- {common_card_name[ind]}")
print(f"{treasure_clue[ind]}\n")
treasure_clues_dm["Sunsword"] = treasure_location[ind]
# Out:
# The Tome of Strahd
# This card tells of history. Knowledge of the ancient will help you better understand your enemy.
#
# -2 of Swords -- Paladin
# I see a sleeping prince, a servant of light and the brother of darkness. The treasure lies with him.
#
# The Holy Symbol of Ravenkind
# This card tells of of a powerful force for good and protection, a holy symbol of great hope.
#
# -2 of Glyphs -- Missionary
# I see a garden dusted with snow, watched over by a scarecrow with a sackcloth grin. Look not to the garden but to the guardian.
#
# The Sunsword
# This is a card of power and strength. It tells of a weapon of vengeance: a sword of sunlight.
#
# -9 of Swords -- Torturer
# There is a town where all is not well. There you will find a house of corruption, and within, a dark room full of still ghosts.

# %%
## DM ONLY
for k, v in treasure_clues_dm.items():
    print(f"{k}\n")
    print(f"--{v}\n")
# Out:
# Tome of Strahd
#
# --The treasure lies in Sergei's tomb (chapter 4, area K85)
#
# Holy Symbol of Ravenkind
#
# --The treasure is hidden inside one of the scarecrows in the garden of the Abbey of Saint Markovia (chapter 8, area S9).
#
# Sunsword
#
# --The treasure is hidden in the attic of the burgomaster’s mansion in Vallaki (chapter 5, area N3s).

# %%
fig, ax = pyplot.subplots(1, 2, squeeze=False, sharex="col", sharey="row")

gs1 = gridspec.GridSpec(1, 3)
gs1.update(wspace=0, hspace=0)
ax[0, 0].set_axis_off()
ax[0, 1].set_axis_off()
pyplot.rcParams["image.aspect"]
strahd_clues_dm = {}
print(f"-Strahd's Enemy")
print(
    f"This card sheds light on one who will help you greatly in the battle against darkness.\n"
)
print(f"--{high_card_name_first}")
print(f"{strahd_enemy_clue[0]}\n")
strahd_clues_dm["Strahd's Enemy"] = strahd_enemy_clue_dm[0]
# fig, ax = plt.subplots(3, 3, squeeze=False)#, sharex="col", sharey="row")

data = pyplot.imread(f"{file_path}\\card_images\\{high_card_name_first}.png")

#         pyplot.rcParams["figure.figsize"] = [30, 15]
#         fig.suptitle("Treasure Cards\n", fontsize=40)
# pyplot.rcParams["image.aspect"]
ax[0, 0].imshow(data)
pyplot.tight_layout()
ax[0, 0].axis("off")

print(f"-Strahd")
print(
    f"Your enemy is a creature of darkness, whose powers are beyond mortality. This card will lead you to him!\n"
)
print(f"--{high_card_name_second}")
print(f"{strahd_location_clue[1]}\n")
print(f"{strahd_location_clue_dm[1]}\n")
strahd_clues_dm["Strahd's Location"] = strahd_location_clue_dm[1]
# fig, ax = plt.subplots(3, 3, squeeze=False)#, sharex="col", sharey="row")

data = pyplot.imread(f"{file_path}\\card_images\\{high_card_name_second}.png")

#         pyplot.rcParams["figure.figsize"] = [30, 15]
#         fig.suptitle("Treasure Cards\n", fontsize=40)
ax[0, 1].imshow(data)
# pyplot.tight_layout()
ax[0, 1].axis("off")
# Out:
# -Strahd's Enemy
# This card sheds light on one who will help you greatly in the battle against darkness.
#
# --Artifact
# Look for an entertaining man with a monkey. This man is more than he seems.
#
# -Strahd
# Your enemy is a creature of darkness, whose powers are beyond mortality. This card will lead you to him!
#
# --Darklord
# He lurks in the depths of darkness, in the one place to which he must return.
#
# Strahd faces the characters in his tomb (area K86).
# (-0.5, 599.5, 839.5, -0.5)

# %%
## DM ONLY
for k, v in strahd_clues_dm.items():
    print(f"{k}\n")
    print(f"--{v}\n")
# Out:
# Strahd's Enemy
#
# --This card refers to Rictavio (see appendix D), who can be found at the Blue Water Inn in Vallaki (chapter 5, area N2). Normally reluctant to accompany the characters, Rictavio changes his tune if the characters tell him about the card reading. He sheds his disguise and introduces himself as Dr. Rudolph van Richten.
#
# The characters might think that Gadof Blinsky, the toymaker of Vallaki (area N7), is the figure they seek, because he has a pet monkey. If they speak to him about this possibility, Blinsky jokes that he and the monkey are “old friends,” but if the characters ask him to come with them to fight Strahd, he politely declines. If the characters tell him about the tarokka reading, Blinsky admits that he acquired the monkey from a half-elf carnival ringmaster named Rictavio.
#
# Strahd's Location
#
# --Strahd faces the characters in his tomb (area K86).

# %% [markdown]
# # Test Code and Scraps

# %%
file_path = Path().absolute()
x = pyplot.imread(f"{file_path}\\card_images\\priest.png")
pyplot.rcParams["figure.figsize"] = [10, 5]
pyplot.imshow(x)

# %%
# deck.loc[deck.suit.str.contains("high")]
#### Test code to see how often the while loop is triggered.
#### By my calculations it should happen 18% of the time, but I'm not seeing that. 
tarokka_deck = create_tarokka_adeck()
common_deck = tarokka_deck.loc[~tarokka_deck.suit.str.contains("High")]
high_deck = tarokka_deck.loc[tarokka_deck.suit.str.contains("High")]
common_draws = common_deck[
    ["card_name", "suit", "treasure_clue", "treasure_location"]
].sample(3)

for_count = 0
for for_count in range(0, 1000000000):
    while_count = 0
    for_high_draws = high_deck[
        [
            "card_name",
            "strahd_enemy_clue",
            "strahd_enemy",
            "strahd_location_clue",
            "strahd_location",
        ]
    ].sample(2)
    high_draw_check = for_high_draws.card_name.str.split("_").tolist()
    if high_draw_check[0][0] == high_draw_check[1][0]:
#         print(high_draws.card_name)
        while (high_draw_check[0][0] == high_draw_check[1][0]):
#             print('for_high_draws:\n', for_high_draws.card_name)
            while_high_draws = high_deck[
                [
                    "card_name",
                    "strahd_enemy_clue",
                    "strahd_enemy",
                    "strahd_location_clue",
                    "strahd_location",
                ]
            ].sample(2)
            high_draw_check = while_high_draws.card_name.str.split("_").tolist()
#             print('while_high_draws:\n', while_high_draws.card_name)
            while_count += 1
            if while_count>=2:
#                 print('for_high_draws:\n', for_high_draws.card_name)
                print('while_high_draws:\n', while_high_draws.card_name)
                print('While count:', while_count)
                print('For count:', for_count)
    for_count += 1
#     print('While count:', while_count)
#     print('For count:', for_count)
# Out:
# while_high_draws:
#  3     broken_one_b
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 1           beast
# Name: card_name, dtype: object
# while_high_draws:
#  14      innocent_b
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 0        artifact
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  8          ghost_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 8          ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  17    mists
# 10     seer
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  10          seer
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 18      raven
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 5         donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 9         ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 9          ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 10       seer
# Name: card_name, dtype: object
# while_high_draws:
#  17        mists
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  10       seer
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  1         beast
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 1       beast
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 14     innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  0      artifact
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  17        mists
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 7    executioner
# Name: card_name, dtype: object
# While count: 2
# For count: 1299
# while_high_draws:
#  6    donjon_b
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 14     innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  11     horseman_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  18    raven
# 17    mists
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 10          seer
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  17    mists
# 18    raven
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 15    marionette_a
# Name: card_name, dtype: object
# While count: 2
# For count: 1796
# while_high_draws:
#  18       raven
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 10            seer
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 0     artifact
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 7      executioner
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 15    marionette_a
# Name: card_name, dtype: object
# While count: 2
# For count: 1931
# while_high_draws:
#  12    horseman_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  4      darklord
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 0        artifact
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 9        ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 17      mists
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 5         donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 18          raven
# Name: card_name, dtype: object
# while_high_draws:
#  0      artifact
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  10       seer
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 10         seer
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 1       beast
# Name: card_name, dtype: object
# while_high_draws:
#  17          mists
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 1           beast
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  1         beast
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 1          beast
# Name: card_name, dtype: object
# While count: 2
# For count: 2608
# while_high_draws:
#  0      artifact
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  6        donjon_b
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  6        donjon_b
# 3    broken_one_b
# Name: card_name, dtype: object
# While count: 2
# For count: 2679
# while_high_draws:
#  5     donjon_a
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  4      darklord
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  12     horseman_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  17         mists
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 10       seer
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 17        mists
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 18          raven
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 4      darklord
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 10         seer
# Name: card_name, dtype: object
# while_high_draws:
#  17        mists
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  10            seer
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  0      artifact
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  8          ghost_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  14     innocent_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 13      innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  1       beast
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 8       ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  0     artifact
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  18      raven
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  5        donjon_a
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  20      tempter_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 19       tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  10            seer
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 9        ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 14     innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  4      darklord
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 19     tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 4         darklord
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 20       tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  10           seer
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  4         darklord
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  17          mists
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  1         beast
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 4    darklord
# Name: card_name, dtype: object
# while_high_draws:
#  17    mists
# 10     seer
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  1     beast
# 10     seer
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  1         beast
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  19      tempter_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 8          ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 10         seer
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 5        donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 20      tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 17          mists
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 10            seer
# Name: card_name, dtype: object
# while_high_draws:
#  8       ghost_a
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  14      innocent_b
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 0      artifact
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 18      raven
# Name: card_name, dtype: object
# while_high_draws:
#  9          ghost_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 17          mists
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 18      raven
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 4         darklord
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 4     darklord
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 17        mists
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 5        donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  11     horseman_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 10            seer
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 19     tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  6    donjon_b
# 1       beast
# Name: card_name, dtype: object
# while_high_draws:
#  5      donjon_a
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 10          seer
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 0         artifact
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 5    donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  10        seer
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 9       ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  4         darklord
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  10        seer
# 0     artifact
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  5     donjon_a
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 19      tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  5        donjon_a
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 5        donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  18         raven
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 20       tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  14     innocent_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  4         darklord
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  10     seer
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 10       seer
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  8       ghost_a
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 12      horseman_b
# Name: card_name, dtype: object
# While count: 2
# For count: 7021
# while_high_draws:
#  19       tempter_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  5        donjon_a
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  20     tempter_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  6     donjon_b
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  9          ghost_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  10     seer
# 17    mists
# Name: card_name, dtype: object
# while_high_draws:
#  10          seer
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 9        ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  9         ghost_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 18      raven
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 13     innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 8       ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 4        darklord
# Name: card_name, dtype: object
# while_high_draws:
#  8    ghost_a
# 9    ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 2     broken_one_a
# Name: card_name, dtype: object
# While count: 2
# For count: 8229
# while_high_draws:
#  2     broken_one_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 4     darklord
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 1            beast
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 1         beast
# Name: card_name, dtype: object
# while_high_draws:
#  5     donjon_a
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 14     innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  10       seer
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  10       seer
# 9     ghost_b
# Name: card_name, dtype: object
# While count: 2
# For count: 8559
# while_high_draws:
#  15    marionette_a
# 6         donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 19     tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 5      donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  14      innocent_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  0        artifact
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  10        seer
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 12     horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  0     artifact
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  20      tempter_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 18        raven
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 0        artifact
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 20    tempter_b
# Name: card_name, dtype: object
# While count: 2
# For count: 9194
# while_high_draws:
#  17    mists
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  5         donjon_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  5        donjon_a
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 13      innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 5         donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 19     tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  6     donjon_b
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  14     innocent_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 12     horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 13     innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 0      artifact
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 4        darklord
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 20       tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  4         darklord
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  20     tempter_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 19       tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  10     seer
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  17    mists
# 10     seer
# Name: card_name, dtype: object
# while_high_draws:
#  1         beast
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 10            seer
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 10       seer
# Name: card_name, dtype: object
# while_high_draws:
#  20     tempter_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 9         ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 5        donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  6         donjon_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 9        ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  10     seer
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 4        darklord
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 6      donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  0         artifact
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  0     artifact
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  6    donjon_b
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 19     tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  0        artifact
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  8         ghost_a
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  4      darklord
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  1     beast
# 18    raven
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 8         ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  6         donjon_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 8       ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  17         mists
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 1         beast
# Name: card_name, dtype: object
# while_high_draws:
#  6    donjon_b
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 0         artifact
# Name: card_name, dtype: object
# while_high_draws:
#  4         darklord
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 4     darklord
# Name: card_name, dtype: object
# while_high_draws:
#  17    mists
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  6     donjon_b
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  10        seer
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 0         artifact
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  6     donjon_b
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 10       seer
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 9          ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  18      raven
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  17      mists
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  14      innocent_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 1       beast
# Name: card_name, dtype: object
# while_high_draws:
#  18        raven
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  7      executioner
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  1     beast
# 17    mists
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 8          ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  4        darklord
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 8         ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 5    donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  18         raven
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 5    donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 9         ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 1       beast
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  8    ghost_a
# 1      beast
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  9    ghost_b
# 8    ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 4     darklord
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 4     darklord
# Name: card_name, dtype: object
# While count: 2
# For count: 13129
# while_high_draws:
#  15    marionette_a
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 8       ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 8       ghost_a
# Name: card_name, dtype: object
# While count: 2
# For count: 13211
# while_high_draws:
#  11    horseman_a
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  1            beast
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 0       artifact
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 1           beast
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  11     horseman_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 6       donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 18          raven
# Name: card_name, dtype: object
# while_high_draws:
#  6    donjon_b
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 1           beast
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 9        ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  10            seer
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 9       ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  5      donjon_a
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  18    raven
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 8          ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 7      executioner
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 20       tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  10       seer
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 18      raven
# Name: card_name, dtype: object
# while_high_draws:
#  11     horseman_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  6        donjon_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 17      mists
# Name: card_name, dtype: object
# while_high_draws:
#  10            seer
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  0         artifact
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  20     tempter_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 4        darklord
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 5        donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  12      horseman_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  5      donjon_a
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 9       ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  18        raven
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 10       seer
# Name: card_name, dtype: object
# while_high_draws:
#  8          ghost_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 0      artifact
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 4        darklord
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 9       ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  9    ghost_b
# 1      beast
# Name: card_name, dtype: object
# while_high_draws:
#  10          seer
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 17         mists
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  6     donjon_b
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  14     innocent_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  5         donjon_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  17        mists
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  18        raven
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  6    donjon_b
# 5    donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 16    marionette_b
# Name: card_name, dtype: object
# While count: 2
# For count: 15445
# while_high_draws:
#  20     tempter_b
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  0     artifact
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 9         ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 9         ghost_b
# Name: card_name, dtype: object
# While count: 2
# For count: 15514
# while_high_draws:
#  17           mists
# 16    marionette_b
# Name: card_name, dtype: object
# ...
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 12      horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 10          seer
# Name: card_name, dtype: object
# while_high_draws:
#  19      tempter_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 10         seer
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  18       raven
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 10            seer
# Name: card_name, dtype: object
# while_high_draws:
#  7    executioner
# 9        ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  9          ghost_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 10          seer
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 13      innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 10          seer
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 12     horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  5        donjon_a
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 17      mists
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  17         mists
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  10         seer
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  1            beast
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  10         seer
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 17        mists
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  9    ghost_b
# 1      beast
# Name: card_name, dtype: object
# while_high_draws:
#  9    ghost_b
# 1      beast
# Name: card_name, dtype: object
# While count: 2
# For count: 43945
# while_high_draws:
#  15    marionette_a
# 20       tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  13      innocent_a
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  10          seer
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  8    ghost_a
# 1      beast
# Name: card_name, dtype: object
# while_high_draws:
#  17           mists
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  6         donjon_b
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 13     innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  10            seer
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 6     donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  18    raven
# 17    mists
# Name: card_name, dtype: object
# while_high_draws:
#  6      donjon_b
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  5        donjon_a
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 11      horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  14      innocent_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  0       artifact
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  6        donjon_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  7     executioner
# 18          raven
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 5         donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  8    ghost_a
# 1      beast
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 4        darklord
# Name: card_name, dtype: object
# while_high_draws:
#  9        ghost_b
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  19     tempter_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 17           mists
# Name: card_name, dtype: object
# while_high_draws:
#  0     artifact
# 17       mists
# Name: card_name, dtype: object
# while_high_draws:
#  5     donjon_a
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 9         ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  17       mists
# 5     donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 8        ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  8          ghost_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  9         ghost_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 0    artifact
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 0    artifact
# Name: card_name, dtype: object
# While count: 2
# For count: 45323
# while_high_draws:
#  16    marionette_b
# 20       tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 4    darklord
# Name: card_name, dtype: object
# while_high_draws:
#  10         seer
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  18         raven
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  6         donjon_b
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  9     ghost_b
# 17      mists
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 2     broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 13      innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  9       ghost_b
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 0      artifact
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  20    tempter_b
# 1         beast
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 8         ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  20     tempter_b
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  12    horseman_b
# 18         raven
# Name: card_name, dtype: object
# while_high_draws:
#  10     seer
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  12     horseman_b
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  20       tempter_b
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 4       darklord
# Name: card_name, dtype: object
# while_high_draws:
#  10        seer
# 4     darklord
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  4    darklord
# 6    donjon_b
# Name: card_name, dtype: object
# while_high_draws:
#  3     broken_one_b
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  9         ghost_b
# 3    broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 13      innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  3    broken_one_b
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 9       ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  19    tempter_a
# 9       ghost_b
# Name: card_name, dtype: object
# While count: 2
# For count: 45942
# while_high_draws:
#  0    artifact
# 8     ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  13    innocent_a
# 1          beast
# Name: card_name, dtype: object
# while_high_draws:
#  14    innocent_b
# 20     tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  5      donjon_a
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  8       ghost_a
# 20    tempter_b
# Name: card_name, dtype: object
# while_high_draws:
#  8     ghost_a
# 4    darklord
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 13      innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  4         darklord
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  10         seer
# 19    tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  4       darklord
# 7    executioner
# Name: card_name, dtype: object
# while_high_draws:
#  2    broken_one_a
# 8         ghost_a
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  1          beast
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  8    ghost_a
# 9    ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 3     broken_one_b
# Name: card_name, dtype: object
# while_high_draws:
#  18           raven
# 3     broken_one_b
# Name: card_name, dtype: object
# While count: 2
# For count: 46481
# while_high_draws:
#  2     broken_one_a
# 10            seer
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  10        seer
# 4     darklord
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 19       tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  6       donjon_b
# 11    horseman_a
# Name: card_name, dtype: object
# while_high_draws:
#  16    marionette_b
# 19       tempter_a
# Name: card_name, dtype: object
# while_high_draws:
#  11     horseman_a
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  11      horseman_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  1     beast
# 10     seer
# Name: card_name, dtype: object
# while_high_draws:
#  10     seer
# 1     beast
# Name: card_name, dtype: object
# while_high_draws:
#  4     darklord
# 18       raven
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 14      innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  11    horseman_a
# 5       donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  0         artifact
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  1           beast
# 2    broken_one_a
# Name: card_name, dtype: object
# while_high_draws:
#  19       tempter_a
# 15    marionette_a
# Name: card_name, dtype: object
# while_high_draws:
#  10          seer
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 18           raven
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 5    donjon_a
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 12    horseman_b
# Name: card_name, dtype: object
# while_high_draws:
#  15    marionette_a
# 7      executioner
# Name: card_name, dtype: object
# while_high_draws:
#  10          seer
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  8        ghost_a
# 14    innocent_b
# Name: card_name, dtype: object
# while_high_draws:
#  0     artifact
# 10        seer
# Name: card_name, dtype: object
# while_high_draws:
#  1            beast
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  0    artifact
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  5       donjon_a
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  2     broken_one_a
# 16    marionette_b
# Name: card_name, dtype: object
# while_high_draws:
#  18      raven
# 9     ghost_b
# Name: card_name, dtype: object
# while_high_draws:
#  5    donjon_a
# 1       beast
# Name: card_name, dtype: object
# while_high_draws:
#  17         mists
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
#  1     beast
# 17    mists
# Name: card_name, dtype: object
# while_high_draws:
#  17          mists
# 7     executioner
# Name: card_name, dtype: object
# while_high_draws:
#  20     tempter_b
# 13    innocent_a
# Name: card_name, dtype: object
# while_high_draws:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-669-7bbed793e8c6> in <module>
#      36             ].sample(2)
#      37             high_draw_check = while_high_draws.card_name.str.split("_").tolist()
# ---> 38             print('while_high_draws:\n', while_high_draws.card_name)
#      39             while_count += 1
#      40             if while_count>=2:
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # newlines imply flush in subprocesses
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     398                                  copy_threshold=self.copy_threshold)
#     399             data.group = group
# --> 400         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     401
#     402     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# C:\ProgramData\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
if high_draw_check
high_draws.head()
# card_list = deck.card_name.str.split("_").tolist()
# for card in card_list:
#     if card.count("a") > 0 or card.count("b") > 0:
#         print(card)
#     else:
#         pass
# Out:
#      card_name                                  strahd_enemy_clue  \
# 5     donjon_a  Search for a troubled young man surrounded by ...
# 7  executioner  Seek out the brother of the devil’s bride. The...
#
#                                         strahd_enemy  \
# 5  This card refers to Victor Vallakovich (see ch...
# 7  This card refers to Ismark Kolyanovich (see ch...
#
#                                 strahd_location_clue  \
# 5  He lurks in a hall of bones, in the dark pits ...
# 7  I see a dark figure on a balcony, looking down...
#
#                                      strahd_location
# 5  Strahd faces the characters in the hall of bon...
# 7  Strahd faces the characters at the overlook (a...

# %% [markdown]
# ### Draw Cards

# %%
def draw_cards():
    tarokka_deck = create_tarokka_deck()
    common_deck = tarokka_deck.loc[~tarokka_deck.suit.str.contains("High")]
    high_deck = tarokka_deck.loc[tarokka_deck.suit.str.contains("High")]
    
    common_draws = common_deck[['card_name', 'suit', 'treasure_clue', 'treasure_location']].sample(3)
    high_draws = high_deck[['card_name','strahd_enemy_clue','strahd_enemy','strahd_location_clue','strahd_location']].sample(2)
    
    common_draw_list = []
    for common_cards in common_draws.iterrows():
        common_card_draw_list.append((common_cards[1][1], common_cards[1][0]))

    common_card_draw_list

    high_card_draw_list = (
        tarokka_deck.loc[tarokka_deck.suit.str.contains("high")]
        .sample(2)
        .card_name.unique()
        .tolist()
    )
    return common_card_draw_list, high_card_draw_list

# %%
[common_draws, high_draws] = draw_cards()
### Draw 3 Cards from common deck
# print(f"Common Draws: \n{common_card_names}\n")
print(f"Common Draws: \n{common_draws}\n")

### Draw 2 cards from the high deck
print(f"High Draws: \n{high_draws}\n")
# Out:
# Common Draws:
# [('glyph_master', 'priest'), ('glyph_2', 'missionary'), ('star_4', 'abjurer')]
#
# High Draws:
# ['seer', 'beast']

# %% [markdown]
# ### Readouts

# %%
print(f"The Tome of Strahd")
print(
    f"This card tells of history. Knowledge of the ancient will help you better understand your enemy.\n{common_draws[0]}\n"
)

print(f"The Holy Symbol of Ravenkind")
print(
    f"This card tells of of a powerful force for good and protection, a holy symbol of great hope.\n{common_draws[1]}\n"
)

print(f"The Sunsword")
print(
    f"This is a card of power and strength. It tells of a weapon of vengeance: a sword of sunlight.\n{common_draws[2]}\n"
)

print(f"Strahd's Enemy")
print(
    f"This card sheds light on one who will help you greatly in the battle against darkness.\n{high_draws[0]}\n"
)

print(f"Strahd")
print(
    f"Your enemy is a creature of darkness, whose powers are beyond mortality. This card will lead you to him!\n{high_draws[1]}\n"
)
# Out:
# The Tome of Strahd
# This card tells of history. Knowledge of the ancient will help you better understand your enemy.
# ('sword_8', 'dictator')
#
# The Holy Symbol of Ravenkind
# This card tells of of a powerful force for good and protection, a holy symbol of great hope.
# ('glyph_6', 'anarchist')
#
# The Sunsword
# This is a card of power and strength. It tells of a weapon of vengeance: a sword of sunlight.
# ('glyph_1', 'monk')
#
# Strahd's Enemy
# This card sheds light on one who will help you greatly in the battle against darkness.
# horseman
#
# Strahd
# Your enemy is a creature of darkness, whose powers are beyond mortality. This card will lead you to him!
# executioner
